# %%
import math
import time
import os

# %%
# !git clone https://github.com/phuongphuongha139-commits/TSP-Nearest-Insertion-3-opt.git
os.chdir("TSP-Nearest-Insertion-3-opt")
# Out:
# Cloning into 'TSP-Nearest-Insertion-3-opt'...
# remote: Enumerating objects: 52, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 52 (delta 6), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (52/52), 61.53 KiB | 2.12 MiB/s, done.
# Resolving deltas: 100% (6/6), done.

# %%
# Known optimal tour lengths (TSPLIB)

OPTIMAL = {
    "berlin52" : 7542,
    "bier127"  : 118282,
    "gil262"   : 2378,
    "linhp318" : 42029,
    "pr439"    :107217,
    "rat575"   : 6773,
    "d657"     : 48912,
    "rat783"   : 8806,
    "pr1002"   : 259045,
    "rl1323"   : 270199,
}

# %%
# ------------------------------------------------------------------------------
#  File I/O
# ------------------------------------------------------------------------------

def read_tsp_file(filepath):
    coords = []
    reading = False
    with open(filepath, 'r') as f:
        for line in f:
            line = line.strip()
            if line == "NODE_COORD_SECTION":
                reading = True
                continue
            if line in ("EOF", "DISPLAY_DATA_SECTION"):
                break
            if reading and line:
                parts = line.split()
                if len(parts) >= 3:
                    coords.append((float(parts[1]), float(parts[2])))
    return coords

# %%
# ------------------------------------------------------------------------------
#  Distance matrix and neighbor lists
# ------------------------------------------------------------------------------

def build_distance_matrix(coords):
    n = len(coords)
    dist = []
    for i in range(n):
        xi, yi = coords[i]
        row = []
        for j in range(n):
            xj, yj = coords[j]
            row.append(int(math.sqrt((xi - xj)**2 + (yi - yj)**2) + 0.5))
        dist.append(row)
    return dist


def build_neighbor_list(dist, k):
    n = len(dist)
    return [
        sorted(range(n), key=lambda j, i=i: dist[i][j])[1:k+1]
        for i in range(n)
    ]

# %%
# ------------------------------------------------------------------------------
#  Tour utilities
# ------------------------------------------------------------------------------

def compute_cost(tour, dist):
    n = len(tour)
    return sum(dist[tour[i]][tour[(i + 1) % n]] for i in range(n))


def validate_tour(tour, n, label=""):
    tag = f"[{label}] " if label else ""
    if len(tour) != n:
        print(f"  {tag}Tour validation: INVALID (length {len(tour)}, expected {n})")
        return False
    if len(set(tour)) != n or min(tour) < 0 or max(tour) >= n:
        print(f"  {tag}Tour validation: INVALID (duplicate or out-of-range city)")
        return False
    print(f"  {tag}Tour validation: valid")
    return True

# %%
# ------------------------------------------------------------------------------
#  Construction heuristics
# ------------------------------------------------------------------------------

def nearest_insertion(dist, verbose=False):
    n = len(dist)
    city1 = min(range(1, n), key=lambda c: dist[0][c])
    tour = [0, city1]
    unvisited = set(range(1, n)) - {city1}
    nearest_dist = {c: min(dist[c][0], dist[c][city1]) for c in unvisited}

    while unvisited:
        chosen = min(unvisited, key=lambda c: nearest_dist[c])

        best_delta, best_pos = math.inf, 1
        for i in range(len(tour)):
            a, b = tour[i], tour[(i + 1) % len(tour)]
            delta = dist[a][chosen] + dist[chosen][b] - dist[a][b]
            if delta < best_delta:
                best_delta, best_pos = delta, i + 1

        tour.insert(best_pos, chosen)
        unvisited.remove(chosen)

        for c in unvisited:
            if dist[c][chosen] < nearest_dist[c]:
                nearest_dist[c] = dist[c][chosen]

        if verbose and (n - len(unvisited)) % 100 == 0:
            print(f"    [{n - len(unvisited):5d}/{n}]  cost: {compute_cost(tour, dist):,}")

    return tour


def cheapest_insertion(dist, verbose=False):
    n = len(dist)
    city1 = min(range(1, n), key=lambda c: dist[0][c])
    tour = [0, city1]
    unvisited = set(range(1, n)) - {city1}

    def best_insertion(c):
        best_delta, best_pos = math.inf, 1
        for i in range(len(tour)):
            a, b = tour[i], tour[(i + 1) % len(tour)]
            delta = dist[a][c] + dist[c][b] - dist[a][b]
            if delta < best_delta:
                best_delta, best_pos = delta, i + 1
        return best_delta, best_pos

    cache = {c: best_insertion(c) for c in unvisited}

    while unvisited:
        chosen = min(unvisited, key=lambda c: cache[c][0])
        _, best_pos = cache[chosen]
        tour.insert(best_pos, chosen)
        unvisited.remove(chosen)
        for c in unvisited:
            cache[c] = best_insertion(c)

        if verbose and (n - len(unvisited)) % 100 == 0:
            print(f"    [{n - len(unvisited):5d}/{n}]  cost: {compute_cost(tour, dist):,}")

    return tour


def farthest_insertion(dist, verbose=False):
    n = len(dist)
    city1 = min(range(1, n), key=lambda c: dist[0][c])
    tour = [0, city1]
    unvisited = set(range(1, n)) - {city1}
    min_dist_to_tour = {c: min(dist[c][0], dist[c][city1]) for c in unvisited}

    while unvisited:
        chosen = max(unvisited, key=lambda c: min_dist_to_tour[c])

        best_delta, best_pos = math.inf, 1
        for i in range(len(tour)):
            a, b = tour[i], tour[(i + 1) % len(tour)]
            delta = dist[a][chosen] + dist[chosen][b] - dist[a][b]
            if delta < best_delta:
                best_delta, best_pos = delta, i + 1

        tour.insert(best_pos, chosen)
        unvisited.remove(chosen)

        for c in unvisited:
            if dist[c][chosen] < min_dist_to_tour[c]:
                min_dist_to_tour[c] = dist[c][chosen]

        if verbose and (n - len(unvisited)) % 100 == 0:
            print(f"    [{n - len(unvisited):5d}/{n}]  cost: {compute_cost(tour, dist):,}")

    return tour

# %%
# ------------------------------------------------------------------------------
#  Local search: 2-opt
# ------------------------------------------------------------------------------

def two_opt(tour, dist, neighbors, verbose=False):
    n = len(tour)
    tour = tour[:]
    pos = {city: idx for idx, city in enumerate(tour)}

    improved = True
    pass_num = 0
    while improved:
        improved = False
        pass_num += 1
        gain_pass = 0

        for idx_a in range(n):
            a = tour[idx_a]
            b = tour[(idx_a + 1) % n]
            dist_ab = dist[a][b]

            for c in neighbors[a]:
                if dist[a][c] >= dist_ab:
                    break
                idx_c = pos[c]
                d = tour[(idx_c + 1) % n]
                if c == b or d == a:
                    continue

                gain = dist_ab + dist[c][d] - dist[a][c] - dist[b][d]
                if gain > 0:
                    left, right = (idx_a + 1) % n, idx_c
                    if left <= right:
                        tour[left:right + 1] = tour[left:right + 1][::-1]
                    else:
                        segment = (tour[left:] + tour[:right + 1])[::-1]
                        for k in range(len(segment)):
                            tour[(left + k) % n] = segment[k]

                    pos = {city: idx for idx, city in enumerate(tour)}
                    b = tour[(idx_a + 1) % n]
                    dist_ab = dist[a][b]
                    gain_pass += gain
                    improved = True
                    break

        if verbose:
            print(f"    Pass {pass_num}: gain {gain_pass:,.0f}  cost {compute_cost(tour, dist):,}")
        if gain_pass == 0:
            break

    return tour

# %%
# ------------------------------------------------------------------------------
#  Local search: 3-opt (helpers + main)
# ------------------------------------------------------------------------------

def _delta_3opt(dist, tour, i, j, k, move_type):
    n = len(tour)
    a, b = tour[i],  tour[(i + 1) % n]
    c, d = tour[j],  tour[(j + 1) % n]
    e, f = tour[k],  tour[(k + 1) % n]
    d0 = dist[a][b] + dist[c][d] + dist[e][f]

    reconnections = {
        1: dist[a][c] + dist[b][d] + dist[e][f],
        2: dist[a][b] + dist[c][e] + dist[d][f],
        3: dist[a][e] + dist[d][b] + dist[c][f],
        4: dist[a][c] + dist[b][e] + dist[d][f],
        5: dist[a][d] + dist[e][b] + dist[c][f],
        6: dist[a][d] + dist[e][c] + dist[b][f],
        7: dist[a][e] + dist[d][c] + dist[b][f],
    }
    return d0 - reconnections.get(move_type, d0)


def _apply_3opt_move(tour, i, j, k, move_type):
    seg0 = tour[:i + 1]
    seg1 = tour[i + 1:j + 1]
    seg2 = tour[j + 1:k + 1]
    seg3 = tour[k + 1:]

    reassembly = {
        1: seg0 + seg1[::-1]        + seg2          + seg3,
        2: seg0 + seg1              + seg2[::-1]    + seg3,
        3: seg0 + (seg1 + seg2)[::-1]               + seg3,
        4: seg0 + seg1[::-1]        + seg2[::-1]    + seg3,
        5: seg0 + seg2              + seg1          + seg3,
        6: seg0 + seg2              + seg1[::-1]    + seg3,
        7: seg0 + seg2[::-1]        + seg1          + seg3,
    }
    return reassembly.get(move_type, tour)


def three_opt(tour, dist, neighbors, verbose=False):

    n = len(tour)
    tour = tour[:]
    pass_num = 0
    skip = [False] * n
    best_cost = compute_cost(tour, dist)

    while True:
        pass_num += 1
        t0 = time.time()
        pos = {city: idx for idx, city in enumerate(tour)}
        move_found = False

        for idx_a in range(n):
            a = tour[idx_a]
            if skip[a]:
                continue

            improved_a = False
            for c in neighbors[a]:
                idx_c = pos[c]
                if idx_c <= idx_a:
                    continue

                for e in neighbors[c]:
                    idx_e = pos[e]
                    if idx_e <= idx_c:
                        continue

                    best_gain, best_move = 0, -1
                    for mv in range(1, 8):
                        gain = _delta_3opt(dist, tour, idx_a, idx_c, idx_e, mv)
                        if gain > best_gain:
                            best_gain, best_move = gain, mv

                    if best_move != -1:
                        tour = _apply_3opt_move(tour, idx_a, idx_c, idx_e, best_move)
                        pos  = {city: idx for idx, city in enumerate(tour)}
                        skip[a] = skip[c] = skip[e] = False
                        move_found = True
                        improved_a = True
                        break
                else:
                    continue
                break

            if not improved_a:
                skip[a] = True

        new_cost = compute_cost(tour, dist)
        if verbose:
            elapsed = time.time() - t0
            print(f"    Pass {pass_num}: {best_cost:,} -> {new_cost:,}  "
                  f"delta={best_cost - new_cost:,}  ({elapsed:.1f}s)")

        if not move_found or new_cost >= best_cost:
            break
        best_cost = new_cost

    return tour

# %%
# ------------------------------------------------------------------------------
#  Pipeline runner
# ------------------------------------------------------------------------------

CONSTRUCTORS = {
    "nearest"  : nearest_insertion,
    "cheapest" : cheapest_insertion,
    "farthest" : farthest_insertion,
}
LOCAL_SEARCH = {
    "2opt" : two_opt,
    "3opt" : three_opt,
}

def run_pipeline(name, dist, neighbors, construct, local_search=None, verbose=False):
    n = len(dist)

    t0 = time.time()
    tour = CONSTRUCTORS[construct](dist, verbose=verbose)
    t_construct = time.time() - t0
    cost_init = compute_cost(tour, dist)

    t1 = time.time()
    if local_search:
        tour = LOCAL_SEARCH[local_search](tour, dist, neighbors, verbose=verbose)
    t_local = time.time() - t1

    cost_final  = compute_cost(tour, dist)
    improvement = (cost_init - cost_final) / cost_init * 100 if cost_init > 0 else 0.0

    return {
        "name"             : name,
        "construction_cost": cost_init,
        "final_cost"       : cost_final,
        "improvement_pct"  : improvement,
        "total_time"       : t_construct + t_local,
    }

# %%
# ------------------------------------------------------------------------------
#  Results display
# ------------------------------------------------------------------------------

def print_results(dataset_name, results):

    optimal = OPTIMAL.get(dataset_name)

    print(f"\nDataset: {dataset_name}", end="")
    if optimal:
        print(f"  (optimal = {optimal:,})", end="")
    print()
    print(f"  {'Pipeline':<22} {'Init Cost':>12} {'Final Cost':>12} {'Improv%':>8} {'Gap%':>8} {'Time(s)':>9}")
    print(f"  {'-' * 77}")

    for r in results:
        gap_str = f"{(r['final_cost'] - optimal) / optimal * 100:>7.2f}%" if optimal else f"{'N/A':>8}"
        print(f"  {r['name']:<22} "
              f"{r['construction_cost']:>12,} "
              f"{r['final_cost']:>12,} "
              f"{r['improvement_pct']:>7.2f}% "
              f"{gap_str} "
              f"{r['total_time']:>9.1f}s")
    print()


def print_summary(all_results):

    pipelines = ["NI", "NI+2opt", "NI+3opt", "CI", "CI+3opt", "FI", "FI+3opt"]

    print("Full pipeline comparison - final tour costs  (* = best for that dataset)\n")
    print(f"  {'Dataset':<12}" + "".join(f"{p:>12}" for p in pipelines))
    print(f"  {'-' * 96}")

    for ds, results in all_results.items():
        costs = [r["final_cost"] for r in results]
        best  = min(costs)
        row   = f"  {ds:<12}"
        for cost in costs:
            marker = "*" if cost == best else " "
            row += f"{cost:>11,}{marker}"
        print(row)

    print()

# %%
# ------------------------------------------------------------------------------
#  Main
# ------------------------------------------------------------------------------

def main():
    # Configuration
    DATA_DIR = "data/"
    K        = 50
    VERBOSE  = True

    DATASETS = [
        "berlin52", "bier127", "gil262", "linhp318",
        "pr439", "rat575", "d657", "rat783", "pr1002", "rl1323"
    ]

    PIPELINES = [
        ("NI",      "nearest",  None),
        ("NI+2opt", "nearest",  "2opt"),
        ("NI+3opt", "nearest",  "3opt"),
        ("CI",      "cheapest", None),
        ("CI+3opt", "cheapest", "3opt"),
        ("FI",      "farthest", None),
        ("FI+3opt", "farthest", "3opt"),
    ]

    all_results = {}

    for ds_name in DATASETS:
        filepath = os.path.join(DATA_DIR, f"{ds_name}.tsp")
        if not os.path.exists(filepath):
            print(f"\nSkipping {ds_name}: file not found at {filepath}")
            continue

        print(f"\nProcessing: {ds_name}")

        coords    = read_tsp_file(filepath)
        n         = len(coords)
        print(f"  {n} cities")

        dist      = build_distance_matrix(coords)
        neighbors = build_neighbor_list(dist, K)

        results = []
        for label, construct, ls in PIPELINES:
            print(f"\n {label}")
            result = run_pipeline(label, dist, neighbors, construct, ls, verbose=VERBOSE)
            validate_tour(CONSTRUCTORS[construct](dist), n, label=label)
            results.append(result)

        print_results(ds_name, results)
        all_results[ds_name] = results

    if all_results:
        print_summary(all_results)


if __name__ == "__main__":
    main()
# Out:
# Processing: berlin52
#   52 cities
#
#  NI
#   [NI] Tour validation: valid
#
#  NI+2opt
#     Pass 1: gain 155  cost 8,836
#     Pass 2: gain 0  cost 8,836
#   [NI+2opt] Tour validation: valid
#
#  NI+3opt
#     Pass 1: 8,991 -> 8,160  delta=831  (0.1s)
#     Pass 2: 8,160 -> 8,009  delta=151  (0.1s)
#     Pass 3: 8,009 -> 7,959  delta=50  (0.1s)
#     Pass 4: 7,959 -> 7,959  delta=0  (0.0s)
#   [NI+3opt] Tour validation: valid
#
#  CI
#   [CI] Tour validation: valid
#
#  CI+3opt
#     Pass 1: 9,004 -> 8,160  delta=844  (0.1s)
#     Pass 2: 8,160 -> 8,009  delta=151  (0.1s)
#     Pass 3: 8,009 -> 7,959  delta=50  (0.1s)
#     Pass 4: 7,959 -> 7,959  delta=0  (0.0s)
#   [CI+3opt] Tour validation: valid
#
#  FI
#   [FI] Tour validation: valid
#
#  FI+3opt
#     Pass 1: 8,275 -> 8,146  delta=129  (0.2s)
#     Pass 2: 8,146 -> 8,146  delta=0  (0.1s)
#   [FI+3opt] Tour validation: valid
#
# Dataset: berlin52  (optimal = 7,542)
#   Pipeline                  Init Cost   Final Cost  Improv%     Gap%   Time(s)
#   -----------------------------------------------------------------------------
#   NI                            8,991        8,991    0.00%   19.21%       0.0s
#   NI+2opt                       8,991        8,836    1.72%   17.16%       0.0s
#   NI+3opt                       8,991        7,959   11.48%    5.53%       0.3s
#   CI                            9,004        9,004    0.00%   19.38%       0.0s
#   CI+3opt                       9,004        7,959   11.61%    5.53%       0.3s
#   FI                            8,275        8,275    0.00%    9.72%       0.0s
#   FI+3opt                       8,275        8,146    1.56%    8.01%       0.2s
#
#
# Processing: bier127
#   127 cities
#
#  NI
#     [  100/127]  cost: 66,346
#   [NI] Tour validation: valid
#
#  NI+2opt
#     [  100/127]  cost: 66,346
#     Pass 1: gain 6,595  cost 139,135
#     Pass 2: gain 2,182  cost 136,953
#     Pass 3: gain 1,567  cost 135,386
#     Pass 4: gain 0  cost 135,386
#   [NI+2opt] Tour validation: valid
#
#  NI+3opt
#     [  100/127]  cost: 66,346
#     Pass 1: 145,730 -> 130,144  delta=15,586  (0.3s)
#     Pass 2: 130,144 -> 123,770  delta=6,374  (0.3s)
#     Pass 3: 123,770 -> 122,705  delta=1,065  (0.1s)
#     Pass 4: 122,705 -> 122,491  delta=214  (0.0s)
#     Pass 5: 122,491 -> 122,491  delta=0  (0.0s)
#   [NI+3opt] Tour validation: valid
#
#  CI
#     [  100/127]  cost: 63,627
#   [CI] Tour validation: valid
#
#  CI+3opt
#     [  100/127]  cost: 63,627
#     Pass 1: 140,647 -> 129,668  delta=10,979  (0.3s)
#     Pass 2: 129,668 -> 126,972  delta=2,696  (0.2s)
#     Pass 3: 126,972 -> 126,670  delta=302  (0.1s)
#     Pass 4: 126,670 -> 126,596  delta=74  (0.0s)
#     Pass 5: 126,596 -> 126,596  delta=0  (0.0s)
#   [CI+3opt] Tour validation: valid
#
#  FI
#     [  100/127]  cost: 126,416
#   [FI] Tour validation: valid
#
#  FI+3opt
#     [  100/127]  cost: 126,416
#     Pass 1: 129,266 -> 124,170  delta=5,096  (0.6s)
#     Pass 2: 124,170 -> 121,117  delta=3,053  (0.2s)
#     Pass 3: 121,117 -> 120,948  delta=169  (0.1s)
#     Pass 4: 120,948 -> 120,492  delta=456  (0.0s)
#     Pass 5: 120,492 -> 120,492  delta=0  (0.0s)
#   [FI+3opt] Tour validation: valid
#
# Dataset: bier127  (optimal = 118,282)
#   Pipeline                  Init Cost   Final Cost  Improv%     Gap%   Time(s)
#   -----------------------------------------------------------------------------
#   NI                          145,730      145,730    0.00%   23.21%       0.0s
#   NI+2opt                     145,730      135,386    7.10%   14.46%       0.0s
#   NI+3opt                     145,730      122,491   15.95%    3.56%       0.7s
#   CI                          140,647      140,647    0.00%   18.91%       0.1s
#   CI+3opt                     140,647      126,596    9.99%    7.03%       0.7s
#   FI                          129,266      129,266    0.00%    9.29%       0.0s
#   FI+3opt                     129,266      120,492    6.79%    1.87%       1.0s
#
#
# Processing: gil262
#   262 cities
#
#  NI
#     [  100/262]  cost: 1,171
#     [  200/262]  cost: 2,198
#   [NI] Tour validation: valid
#
#  NI+2opt
#     [  100/262]  cost: 1,171
#     [  200/262]  cost: 2,198
#     Pass 1: gain 199  cost 2,714
#     Pass 2: gain 61  cost 2,653
#     Pass 3: gain 15  cost 2,638
#     Pass 4: gain 0  cost 2,638
#   [NI+2opt] Tour validation: valid
#
#  NI+3opt
#     [  100/262]  cost: 1,171
#     [  200/262]  cost: 2,198
#     Pass 1: 2,913 -> 2,566  delta=347  (0.7s)
#     Pass 2: 2,566 -> 2,496  delta=70  (0.5s)
#     Pass 3: 2,496 -> 2,494  delta=2  (0.1s)
#     Pass 4: 2,494 -> 2,494  delta=0  (0.0s)
#   [NI+3opt] Tour validation: valid
#
#  CI
#     [  100/262]  cost: 1,153
#     [  200/262]  cost: 2,051
#   [CI] Tour validation: valid
#
#  CI+3opt
#     [  100/262]  cost: 1,153
#     [  200/262]  cost: 2,051
#     Pass 1: 2,790 -> 2,581  delta=209  (0.8s)
#     Pass 2: 2,581 -> 2,532  delta=49  (0.4s)
#     Pass 3: 2,532 -> 2,531  delta=1  (0.1s)
#     Pass 4: 2,531 -> 2,531  delta=0  (0.0s)
#   [CI+3opt] Tour validation: valid
#
#  FI
#     [  100/262]  cost: 2,011
#     [  200/262]  cost: 2,447
#   [FI] Tour validation: valid
#
#  FI+3opt
#     [  100/262]  cost: 2,011
#     [  200/262]  cost: 2,447
#     Pass 1: 2,554 -> 2,525  delta=29  (3.0s)
#     Pass 2: 2,525 -> 2,502  delta=23  (0.1s)
#     Pass 3: 2,502 -> 2,497  delta=5  (0.0s)
#     Pass 4: 2,497 -> 2,503  delta=-6  (0.0s)
#   [FI+3opt] Tour validation: valid
#
# Dataset: gil262  (optimal = 2,378)
#   Pipeline                  Init Cost   Final Cost  Improv%     Gap%   Time(s)
#   -----------------------------------------------------------------------------
#   NI                            2,913        2,913    0.00%   22.50%       0.0s
#   NI+2opt                       2,913        2,638    9.44%   10.93%       0.0s
#   NI+3opt                       2,913        2,494   14.38%    4.88%       1.4s
#   CI                            2,790        2,790    0.00%   17.33%       0.8s
#   CI+3opt                       2,790        2,531    9.28%    6.43%       1.8s
#   FI                            2,554        2,554    0.00%    7.40%       0.0s
#   FI+3opt                       2,554        2,503    2.00%    5.26%       3.2s
#
#
# Processing: linhp318
#   318 cities
#
#  NI
#     [  100/318]  cost: 15,978
#     [  200/318]  cost: 31,889
#     [  300/318]  cost: 46,814
#   [NI] Tour validation: valid
#
#  NI+2opt
#     [  100/318]  cost: 15,978
#     [  200/318]  cost: 31,889
#     [  300/318]  cost: 46,814
#     Pass 1: gain 2,592  cost 49,738
#     Pass 2: gain 768  cost 48,970
#     Pass 3: gain 1,120  cost 47,850
#     Pass 4: gain 71  cost 47,779
#     Pass 5: gain 0  cost 47,779
#   [NI+2opt] Tour validation: valid
#
#  NI+3opt
#     [  100/318]  cost: 15,978
#     [  200/318]  cost: 31,889
#     [  300/318]  cost: 46,814
#     Pass 1: 52,330 -> 45,293  delta=7,037  (1.1s)
#     Pass 2: 45,293 -> 43,673  delta=1,620  (0.7s)
#     Pass 3: 43,673 -> 43,673  delta=0  (0.3s)
#   [NI+3opt] Tour validation: valid
#
#  CI
#     [  100/318]  cost: 14,302
#     [  200/318]  cost: 28,771
#     [  300/318]  cost: 43,739
#   [CI] Tour validation: valid
#
#  CI+3opt
#     [  100/318]  cost: 14,302
#     [  200/318]  cost: 28,771
#     [  300/318]  cost: 43,739
#     Pass 1: 49,470 -> 44,766  delta=4,704  (1.1s)
#     Pass 2: 44,766 -> 44,402  delta=364  (0.6s)
#     Pass 3: 44,402 -> 44,235  delta=167  (0.1s)
#     Pass 4: 44,235 -> 44,235  delta=0  (0.0s)
#   [CI+3opt] Tour validation: valid
#
#  FI
#     [  100/318]  cost: 35,630
#     [  200/318]  cost: 42,566
#     [  300/318]  cost: 45,059
#   [FI] Tour validation: valid
#
#  FI+3opt
#     [  100/318]  cost: 35,630
#     [  200/318]  cost: 42,566
#     [  300/318]  cost: 45,059
#     Pass 1: 45,154 -> 44,183  delta=971  (2.3s)
#     Pass 2: 44,183 -> 43,646  delta=537  (0.4s)
#     Pass 3: 43,646 -> 43,646  delta=0  (0.1s)
#   [FI+3opt] Tour validation: valid
#
# Dataset: linhp318  (optimal = 42,029)
#   Pipeline                  Init Cost   Final Cost  Improv%     Gap%   Time(s)
#   -----------------------------------------------------------------------------
#   NI                           52,330       52,330    0.00%   24.51%       0.0s
#   NI+2opt                      52,330       47,779    8.70%   13.68%       0.0s
#   NI+3opt                      52,330       43,673   16.54%    3.91%       2.1s
#   CI                           49,470       49,470    0.00%   17.70%       1.3s
#   CI+3opt                      49,470       44,235   10.58%    5.25%       3.1s
#   FI                           45,154       45,154    0.00%    7.44%       0.1s
#   FI+3opt                      45,154       43,646    3.34%    3.85%       2.8s
#
#
# Processing: pr439
#   439 cities
#
#  NI
#     [  100/439]  cost: 23,775
#     [  200/439]  cost: 43,330
#     [  300/439]  cost: 61,758
#     [  400/439]  cost: 103,367
#   [NI] Tour validation: valid
#
#  NI+2opt
#     [  100/439]  cost: 23,775
#     [  200/439]  cost: 43,330
#     [  300/439]  cost: 61,758
#     [  400/439]  cost: 103,367
#     Pass 1: gain 2,119  cost 130,662
#     Pass 2: gain 2,718  cost 127,944
#     Pass 3: gain 1,326  cost 126,618
#     Pass 4: gain 520  cost 126,098
#     Pass 5: gain 1,332  cost 124,766
#     Pass 6: gain 287  cost 124,479
#     Pass 7: gain 0  cost 124,479
#   [NI+2opt] Tour validation: valid
#
#  NI+3opt
#     [  100/439]  cost: 23,775
#     [  200/439]  cost: 43,330
#     [  300/439]  cost: 61,758
#     [  400/439]  cost: 103,367
#     Pass 1: 132,781 -> 121,353  delta=11,428  (1.5s)
#     Pass 2: 121,353 -> 119,587  delta=1,766  (0.3s)
#     Pass 3: 119,587 -> 119,344  delta=243  (0.1s)
#     Pass 4: 119,344 -> 119,344  delta=0  (0.0s)
#   [NI+3opt] Tour validation: valid
#
#  CI
#     [  100/439]  cost: 22,298
#     [  200/439]  cost: 41,346
#     [  300/439]  cost: 59,276
#     [  400/439]  cost: 101,166
#   [CI] Tour validation: valid
#
#  CI+3opt
#     [  100/439]  cost: 22,298
#     [  200/439]  cost: 41,346
#     [  300/439]  cost: 59,276
#     [  400/439]  cost: 101,166
#     Pass 1: 130,184 -> 120,650  delta=9,534  (1.7s)
#     Pass 2: 120,650 -> 118,291  delta=2,359  (0.8s)
#     Pass 3: 118,291 -> 118,248  delta=43  (0.4s)
#     Pass 4: 118,248 -> 118,037  delta=211  (0.1s)
#     Pass 5: 118,037 -> 118,037  delta=0  (0.0s)
#   [CI+3opt] Tour validation: valid
#
#  FI
#     [  100/439]  cost: 83,626
#     [  200/439]  cost: 102,322
#     [  300/439]  cost: 111,425
#     [  400/439]  cost: 118,625
#   [FI] Tour validation: valid
#
#  FI+3opt
#     [  100/439]  cost: 83,626
#     [  200/439]  cost: 102,322
#     [  300/439]  cost: 111,425
#     [  400/439]  cost: 118,625
#     Pass 1: 120,524 -> 118,389  delta=2,135  (3.2s)
#     Pass 2: 118,389 -> 115,965  delta=2,424  (0.4s)
#     Pass 3: 115,965 -> 115,845  delta=120  (0.3s)
#     Pass 4: 115,845 -> 115,261  delta=584  (0.0s)
#     Pass 5: 115,261 -> 115,132  delta=129  (0.0s)
#     Pass 6: 115,132 -> 115,132  delta=0  (0.0s)
#   [FI+3opt] Tour validation: valid
#
# Dataset: pr439  (optimal = 107,217)
#   Pipeline                  Init Cost   Final Cost  Improv%     Gap%   Time(s)
#   -----------------------------------------------------------------------------
#   NI                          132,781      132,781    0.00%   23.84%       0.1s
#   NI+2opt                     132,781      124,479    6.25%   16.10%       0.1s
#   NI+3opt                     132,781      119,344   10.12%   11.31%       2.0s
#   CI                          130,184      130,184    0.00%   21.42%       3.9s
#   CI+3opt                     130,184      118,037    9.33%   10.09%       7.7s
#   FI                          120,524      120,524    0.00%   12.41%       0.1s
#   FI+3opt                     120,524      115,132    4.47%    7.38%       4.1s
#
#
# Processing: rat575
#   575 cities
#
#  NI
#     [  100/575]  cost: 1,572
#     [  200/575]  cost: 3,057
#     [  300/575]  cost: 4,535
#     [  400/575]  cost: 5,958
#     [  500/575]  cost: 7,372
#   [NI] Tour validation: valid
#
#  NI+2opt
#     [  100/575]  cost: 1,572
#     [  200/575]  cost: 3,057
#     [  300/575]  cost: 4,535
#     [  400/575]  cost: 5,958
#     [  500/575]  cost: 7,372
#     Pass 1: gain 263  cost 8,214
#     Pass 2: gain 144  cost 8,070
#     Pass 3: gain 376  cost 7,694
#     Pass 4: gain 55  cost 7,639
#     Pass 5: gain 2  cost 7,637
#     Pass 6: gain 0  cost 7,637
#   [NI+2opt] Tour validation: valid
#
#  NI+3opt
#     [  100/575]  cost: 1,572
#     [  200/575]  cost: 3,057
#     [  300/575]  cost: 4,535
#     [  400/575]  cost: 5,958
#     [  500/575]  cost: 7,372
#     Pass 1: 8,477 -> 7,376  delta=1,101  (1.8s)
#     Pass 2: 7,376 -> 7,310  delta=66  (1.2s)
#     Pass 3: 7,310 -> 7,241  delta=69  (0.3s)
#     Pass 4: 7,241 -> 7,240  delta=1  (0.1s)
#     Pass 5: 7,240 -> 7,241  delta=-1  (0.0s)
#   [NI+3opt] Tour validation: valid
#
#  CI
#     [  100/575]  cost: 1,239
#     [  200/575]  cost: 2,638
#     [  300/575]  cost: 4,002
#     [  400/575]  cost: 5,358
#     [  500/575]  cost: 6,687
#   [CI] Tour validation: valid
#
#  CI+3opt
#     [  100/575]  cost: 1,239
#     [  200/575]  cost: 2,638
#     [  300/575]  cost: 4,002
#     [  400/575]  cost: 5,358
#     [  500/575]  cost: 6,687
#     Pass 1: 7,981 -> 7,414  delta=567  (1.9s)
#     Pass 2: 7,414 -> 7,260  delta=154  (0.7s)
#     Pass 3: 7,260 -> 7,200  delta=60  (0.2s)
#     Pass 4: 7,200 -> 7,189  delta=11  (0.0s)
#     Pass 5: 7,189 -> 7,189  delta=0  (0.0s)
#   [CI+3opt] Tour validation: valid
#
#  FI
#     [  100/575]  cost: 3,637
#     [  200/575]  cost: 5,027
#     [  300/575]  cost: 6,045
#     [  400/575]  cost: 6,674
#     [  500/575]  cost: 7,265
#   [FI] Tour validation: valid
#
#  FI+3opt
#     [  100/575]  cost: 3,637
#     [  200/575]  cost: 5,027
#     [  300/575]  cost: 6,045
#     [  400/575]  cost: 6,674
#     [  500/575]  cost: 7,265
#     Pass 1: 7,496 -> 7,270  delta=226  (2.3s)
#     Pass 2: 7,270 -> 7,187  delta=83  (0.5s)
#     Pass 3: 7,187 -> 7,129  delta=58  (0.2s)
#     Pass 4: 7,129 -> 7,129  delta=0  (0.1s)
#   [FI+3opt] Tour validation: valid
#
# Dataset: rat575  (optimal = 6,773)
#   Pipeline                  Init Cost   Final Cost  Improv%     Gap%   Time(s)
#   -----------------------------------------------------------------------------
#   NI                            8,477        8,477    0.00%   25.16%       0.1s
#   NI+2opt                       8,477        7,637    9.91%   12.76%       0.1s
#   NI+3opt                       8,477        7,241   14.58%    6.91%       3.5s
#   CI                            7,981        7,981    0.00%   17.84%       9.5s
#   CI+3opt                       7,981        7,189    9.92%    6.14%      12.3s
#   FI                            7,496        7,496    0.00%   10.67%       0.1s
#   FI+3opt                       7,496        7,129    4.90%    5.26%       3.2s
#
#
# Processing: d657
#   657 cities
#
#  NI
#     [  100/657]  cost: 10,205
#     [  200/657]  cost: 18,279
#     [  300/657]  cost: 25,448
#     [  400/657]  cost: 34,775
#     [  500/657]  cost: 42,869
#     [  600/657]  cost: 54,490
#   [NI] Tour validation: valid
#
#  NI+2opt
#     [  100/657]  cost: 10,205
#     [  200/657]  cost: 18,279
#     [  300/657]  cost: 25,448
#     [  400/657]  cost: 34,775
#     [  500/657]  cost: 42,869
#     [  600/657]  cost: 54,490
#     Pass 1: gain 1,724  cost 58,631
#     Pass 2: gain 1,237  cost 57,394
#     Pass 3: gain 471  cost 56,923
#     Pass 4: gain 556  cost 56,367
#     Pass 5: gain 7  cost 56,360
#     Pass 6: gain 0  cost 56,360
#   [NI+2opt] Tour validation: valid
#
#  NI+3opt
#     [  100/657]  cost: 10,205
#     [  200/657]  cost: 18,279
#     [  300/657]  cost: 25,448
#     [  400/657]  cost: 34,775
#     [  500/657]  cost: 42,869
#     [  600/657]  cost: 54,490
#     Pass 1: 60,355 -> 53,935  delta=6,420  (3.1s)
#     Pass 2: 53,935 -> 52,917  delta=1,018  (1.7s)
#     Pass 3: 52,917 -> 52,475  delta=442  (0.5s)
#     Pass 4: 52,475 -> 52,430  delta=45  (0.2s)
#     Pass 5: 52,430 -> 52,306  delta=124  (0.0s)
#     Pass 6: 52,306 -> 52,306  delta=0  (0.0s)
#   [NI+3opt] Tour validation: valid
#
#  CI
#     [  100/657]  cost: 9,614
#     [  200/657]  cost: 17,140
#     [  300/657]  cost: 24,546
#     [  400/657]  cost: 32,180
#     [  500/657]  cost: 41,248
#     [  600/657]  cost: 50,734
#   [CI] Tour validation: valid
#
#  CI+3opt
#     [  100/657]  cost: 9,614
#     [  200/657]  cost: 17,140
#     [  300/657]  cost: 24,546
#     [  400/657]  cost: 32,180
#     [  500/657]  cost: 41,248
#     [  600/657]  cost: 50,734
#     Pass 1: 57,964 -> 53,304  delta=4,660  (2.9s)
#     Pass 2: 53,304 -> 52,527  delta=777  (1.0s)
#     Pass 3: 52,527 -> 52,516  delta=11  (0.2s)
#     Pass 4: 52,516 -> 52,414  delta=102  (0.0s)
#     Pass 5: 52,414 -> 52,414  delta=0  (0.0s)
#   [CI+3opt] Tour validation: valid
#
#  FI
#     [  100/657]  cost: 29,125
#     [  200/657]  cost: 38,517
#     [  300/657]  cost: 44,672
#     [  400/657]  cost: 48,386
#     [  500/657]  cost: 51,214
#     [  600/657]  cost: 53,009
#   [FI] Tour validation: valid
#
#  FI+3opt
#     [  100/657]  cost: 29,125
#     [  200/657]  cost: 38,517
#     [  300/657]  cost: 44,672
#     [  400/657]  cost: 48,386
#     [  500/657]  cost: 51,214
#     [  600/657]  cost: 53,009
#     Pass 1: 53,508 -> 52,312  delta=1,196  (4.4s)
#     Pass 2: 52,312 -> 52,041  delta=271  (0.6s)
#     Pass 3: 52,041 -> 52,183  delta=-142  (0.1s)
#   [FI+3opt] Tour validation: valid
#
# Dataset: d657  (optimal = 48,912)
#   Pipeline                  Init Cost   Final Cost  Improv%     Gap%   Time(s)
#   -----------------------------------------------------------------------------
#   NI                           60,355       60,355    0.00%   23.40%       0.3s
#   NI+2opt                      60,355       56,360    6.62%   15.23%       0.3s
#   NI+3opt                      60,355       52,306   13.34%    6.94%       5.8s
#   CI                           57,964       57,964    0.00%   18.51%      16.3s
#   CI+3opt                      57,964       52,414    9.57%    7.16%      20.8s
#   FI                           53,508       53,508    0.00%    9.40%       0.2s
#   FI+3opt                      53,508       52,183    2.48%    6.69%       5.3s
#
#
# Processing: rat783
#   783 cities
#
#  NI
#     [  100/783]  cost: 1,320
#     [  200/783]  cost: 2,677
#     [  300/783]  cost: 4,046
#     [  400/783]  cost: 5,348
#     [  500/783]  cost: 6,782
#     [  600/783]  cost: 8,209
#     [  700/783]  cost: 9,504
#   [NI] Tour validation: valid
#
#  NI+2opt
#     [  100/783]  cost: 1,320
#     [  200/783]  cost: 2,677
#     [  300/783]  cost: 4,046
#     [  400/783]  cost: 5,348
#     [  500/783]  cost: 6,782
#     [  600/783]  cost: 8,209
#     [  700/783]  cost: 9,504
#     Pass 1: gain 172  cost 10,705
#     Pass 2: gain 434  cost 10,271
#     Pass 3: gain 161  cost 10,110
#     Pass 4: gain 141  cost 9,969
#     Pass 5: gain 27  cost 9,942
#     Pass 6: gain 24  cost 9,918
#     Pass 7: gain 0  cost 9,918
#   [NI+2opt] Tour validation: valid
#
#  NI+3opt
#     [  100/783]  cost: 1,320
#     [  200/783]  cost: 2,677
#     [  300/783]  cost: 4,046
#     [  400/783]  cost: 5,348
#     [  500/783]  cost: 6,782
#     [  600/783]  cost: 8,209
#     [  700/783]  cost: 9,504
#     Pass 1: 10,877 -> 9,577  delta=1,300  (2.7s)
#     Pass 2: 9,577 -> 9,427  delta=150  (1.1s)
#     Pass 3: 9,427 -> 9,420  delta=7  (0.3s)
#     Pass 4: 9,420 -> 9,387  delta=33  (0.1s)
#     Pass 5: 9,387 -> 9,385  delta=2  (0.0s)
#     Pass 6: 9,385 -> 9,387  delta=-2  (0.0s)
#   [NI+3opt] Tour validation: valid
#
#  CI
#     [  100/783]  cost: 1,232
#     [  200/783]  cost: 2,521
#     [  300/783]  cost: 3,820
#     [  400/783]  cost: 5,125
#     [  500/783]  cost: 6,483
#     [  600/783]  cost: 7,750
#     [  700/783]  cost: 9,091
#   [CI] Tour validation: valid
#
#  CI+3opt
#     [  100/783]  cost: 1,232
#     [  200/783]  cost: 2,521
#     [  300/783]  cost: 3,820
#     [  400/783]  cost: 5,125
#     [  500/783]  cost: 6,483
#     [  600/783]  cost: 7,750
#     [  700/783]  cost: 9,091
#     Pass 1: 10,384 -> 9,584  delta=800  (3.7s)
#     Pass 2: 9,584 -> 9,365  delta=219  (2.0s)
#     Pass 3: 9,365 -> 9,326  delta=39  (0.4s)
#     Pass 4: 9,326 -> 9,331  delta=-5  (0.1s)
#   [CI+3opt] Tour validation: valid
#
#  FI
#     [  100/783]  cost: 4,297
#     [  200/783]  cost: 5,810
#     [  300/783]  cost: 7,067
#     [  400/783]  cost: 7,895
#     [  500/783]  cost: 8,577
#     [  600/783]  cost: 9,134
#     [  700/783]  cost: 9,583
#   [FI] Tour validation: valid
#
#  FI+3opt
#     [  100/783]  cost: 4,297
#     [  200/783]  cost: 5,810
#     [  300/783]  cost: 7,067
#     [  400/783]  cost: 7,895
#     [  500/783]  cost: 8,577
#     [  600/783]  cost: 9,134
#     [  700/783]  cost: 9,583
#     Pass 1: 9,731 -> 9,406  delta=325  (3.3s)
#     Pass 2: 9,406 -> 9,322  delta=84  (0.7s)
#     Pass 3: 9,322 -> 9,322  delta=0  (0.1s)
#   [FI+3opt] Tour validation: valid
#
# Dataset: rat783  (optimal = 8,806)
#   Pipeline                  Init Cost   Final Cost  Improv%     Gap%   Time(s)
#   -----------------------------------------------------------------------------
#   NI                           10,877       10,877    0.00%   23.52%       0.2s
#   NI+2opt                      10,877        9,918    8.82%   12.63%       0.2s
#   NI+3opt                      10,877        9,387   13.70%    6.60%       4.4s
#   CI                           10,384       10,384    0.00%   17.92%      25.7s
#   CI+3opt                      10,384        9,331   10.14%    5.96%      31.7s
#   FI                            9,731        9,731    0.00%   10.50%       0.2s
#   FI+3opt                       9,731        9,322    4.20%    5.86%       4.4s
#
#
# Processing: pr1002
#   1002 cities
#
#  NI
#     [  100/1002]  cost: 33,449
#     [  200/1002]  cost: 63,392
#     [  300/1002]  cost: 93,268
#     [  400/1002]  cost: 127,771
#     [  500/1002]  cost: 155,256
#     [  600/1002]  cost: 180,924
#     [  700/1002]  cost: 217,141
#     [  800/1002]  cost: 244,725
#     [  900/1002]  cost: 271,456
#     [ 1000/1002]  cost: 304,814
#   [NI] Tour validation: valid
#
#  NI+2opt
#     [  100/1002]  cost: 33,449
#     [  200/1002]  cost: 63,392
#     [  300/1002]  cost: 93,268
#     [  400/1002]  cost: 127,771
#     [  500/1002]  cost: 155,256
#     [  600/1002]  cost: 180,924
#     [  700/1002]  cost: 217,141
#     [  800/1002]  cost: 244,725
#     [  900/1002]  cost: 271,456
#     [ 1000/1002]  cost: 304,814
#     Pass 1: gain 10,435  cost 296,995
#     Pass 2: gain 2,920  cost 294,075
#     Pass 3: gain 1,458  cost 292,617
#     Pass 4: gain 772  cost 291,845
#     Pass 5: gain 1,412  cost 290,433
#     Pass 6: gain 0  cost 290,433
#   [NI+2opt] Tour validation: valid
#
#  NI+3opt
#     [  100/1002]  cost: 33,449
#     [  200/1002]  cost: 63,392
#     [  300/1002]  cost: 93,268
#     [  400/1002]  cost: 127,771
#     [  500/1002]  cost: 155,256
#     [  600/1002]  cost: 180,924
#     [  700/1002]  cost: 217,141
#     [  800/1002]  cost: 244,725
#     [  900/1002]  cost: 271,456
#     [ 1000/1002]  cost: 304,814
#     Pass 1: 307,430 -> 282,933  delta=24,497  (5.0s)
#     Pass 2: 282,933 -> 279,138  delta=3,795  (1.7s)
#     Pass 3: 279,138 -> 276,992  delta=2,146  (0.6s)
#     Pass 4: 276,992 -> 277,340  delta=-348  (0.3s)
#   [NI+3opt] Tour validation: valid
#
#  CI
#     [  100/1002]  cost: 33,482
#     [  200/1002]  cost: 59,608
#     [  300/1002]  cost: 90,417
#     [  400/1002]  cost: 125,008
#     [  500/1002]  cost: 150,741
#     [  600/1002]  cost: 178,157
#     [  700/1002]  cost: 211,527
#     [  800/1002]  cost: 237,954
#     [  900/1002]  cost: 265,712
#     [ 1000/1002]  cost: 302,212
#   [CI] Tour validation: valid
#
#  CI+3opt
#     [  100/1002]  cost: 33,482
#     [  200/1002]  cost: 59,608
#     [  300/1002]  cost: 90,417
#     [  400/1002]  cost: 125,008
#     [  500/1002]  cost: 150,741
#     [  600/1002]  cost: 178,157
#     [  700/1002]  cost: 211,527
#     [  800/1002]  cost: 237,954
#     [  900/1002]  cost: 265,712
#     [ 1000/1002]  cost: 302,212
#     Pass 1: 304,828 -> 281,645  delta=23,183  (4.0s)
#     Pass 2: 281,645 -> 278,821  delta=2,824  (1.1s)
#     Pass 3: 278,821 -> 278,682  delta=139  (0.4s)
#     Pass 4: 278,682 -> 278,682  delta=0  (0.0s)
#   [CI+3opt] Tour validation: valid
#
#  FI
#     [  100/1002]  cost: 129,418
#     [  200/1002]  cost: 169,496
#     [  300/1002]  cost: 198,760
#     [  400/1002]  cost: 219,796
#     [  500/1002]  cost: 239,061
#     [  600/1002]  cost: 251,058
#     [  700/1002]  cost: 261,840
#     [  800/1002]  cost: 270,849
#     [  900/1002]  cost: 279,364
#     [ 1000/1002]  cost: 284,447
#   [FI] Tour validation: valid
#
#  FI+3opt
#     [  100/1002]  cost: 129,418
#     [  200/1002]  cost: 169,496
#     [  300/1002]  cost: 198,760
#     [  400/1002]  cost: 219,796
#     [  500/1002]  cost: 239,061
#     [  600/1002]  cost: 251,058
#     [  700/1002]  cost: 261,840
#     [  800/1002]  cost: 270,849
#     [  900/1002]  cost: 279,364
#     [ 1000/1002]  cost: 284,447
#     Pass 1: 284,485 -> 275,869  delta=8,616  (4.9s)
#     Pass 2: 275,869 -> 271,244  delta=4,625  (1.2s)
#     Pass 3: 271,244 -> 271,173  delta=71  (0.4s)
#     Pass 4: 271,173 -> 271,173  delta=0  (0.0s)
#   [FI+3opt] Tour validation: valid
#
# Dataset: pr1002  (optimal = 259,045)
#   Pipeline                  Init Cost   Final Cost  Improv%     Gap%   Time(s)
#   -----------------------------------------------------------------------------
#   NI                          307,430      307,430    0.00%   18.68%       0.4s
#   NI+2opt                     307,430      290,433    5.53%   12.12%       0.4s
#   NI+3opt                     307,430      277,340    9.79%    7.06%       8.0s
#   CI                          304,828      304,828    0.00%   17.67%      65.1s
#   CI+3opt                     304,828      278,682    8.58%    7.58%      70.3s
#   FI                          284,485      284,485    0.00%    9.82%       0.8s
#   FI+3opt                     284,485      271,173    4.68%    4.68%       7.0s
#
#
# Processing: rl1323
#   1323 cities
#
#  NI
#     [  100/1323]  cost: 26,153
#     [  200/1323]  cost: 52,348
#     [  300/1323]  cost: 79,780
#     [  400/1323]  cost: 109,086
#     [  500/1323]  cost: 136,634
#     [  600/1323]  cost: 161,577
#     [  700/1323]  cost: 187,510
#     [  800/1323]  cost: 214,260
#     [  900/1323]  cost: 237,181
#     [ 1000/1323]  cost: 261,355
#     [ 1100/1323]  cost: 287,123
#     [ 1200/1323]  cost: 315,370
#     [ 1300/1323]  cost: 338,873
#   [NI] Tour validation: valid
#
#  NI+2opt
#     [  100/1323]  cost: 26,153
#     [  200/1323]  cost: 52,348
#     [  300/1323]  cost: 79,780
#     [  400/1323]  cost: 109,086
#     [  500/1323]  cost: 136,634
#     [  600/1323]  cost: 161,577
#     [  700/1323]  cost: 187,510
#     [  800/1323]  cost: 214,260
#     [  900/1323]  cost: 237,181
#     [ 1000/1323]  cost: 261,355
#     [ 1100/1323]  cost: 287,123
#     [ 1200/1323]  cost: 315,370
#     [ 1300/1323]  cost: 338,873
#     Pass 1: gain 10,774  cost 341,864
#     Pass 2: gain 16,088  cost 325,776
#     Pass 3: gain 2,205  cost 323,571
#     Pass 4: gain 1,402  cost 322,169
#     Pass 5: gain 994  cost 321,175
#     Pass 6: gain 3,836  cost 317,339
#     Pass 7: gain 3,259  cost 314,080
#     Pass 8: gain 1,039  cost 313,041
#     Pass 9: gain 2,275  cost 310,766
#     Pass 10: gain 3,525  cost 307,241
#     Pass 11: gain 317  cost 306,924
#     Pass 12: gain 0  cost 306,924
#   [NI+2opt] Tour validation: valid
#
#  NI+3opt
#     [  100/1323]  cost: 26,153
#     [  200/1323]  cost: 52,348
#     [  300/1323]  cost: 79,780
#     [  400/1323]  cost: 109,086
#     [  500/1323]  cost: 136,634
#     [  600/1323]  cost: 161,577
#     [  700/1323]  cost: 187,510
#     [  800/1323]  cost: 214,260
#     [  900/1323]  cost: 237,181
#     [ 1000/1323]  cost: 261,355
#     [ 1100/1323]  cost: 287,123
#     [ 1200/1323]  cost: 315,370
#     [ 1300/1323]  cost: 338,873
#     Pass 1: 352,638 -> 304,147  delta=48,491  (6.3s)
#     Pass 2: 304,147 -> 296,012  delta=8,135  (2.4s)
#     Pass 3: 296,012 -> 295,106  delta=906  (1.1s)
#     Pass 4: 295,106 -> 293,860  delta=1,246  (0.5s)
#     Pass 5: 293,860 -> 293,768  delta=92  (0.3s)
#     Pass 6: 293,768 -> 293,791  delta=-23  (0.2s)
#   [NI+3opt] Tour validation: valid
#
#  CI
#     [  100/1323]  cost: 24,453
#     [  200/1323]  cost: 49,908
#     [  300/1323]  cost: 79,260
#     [  400/1323]  cost: 103,595
#     [  500/1323]  cost: 129,893
#     [  600/1323]  cost: 150,438
#     [  700/1323]  cost: 172,177
#     [  800/1323]  cost: 199,153
#     [  900/1323]  cost: 229,530
#     [ 1000/1323]  cost: 255,676
#     [ 1100/1323]  cost: 281,201
#     [ 1200/1323]  cost: 306,625
#     [ 1300/1323]  cost: 327,547
#   [CI] Tour validation: valid
#
#  CI+3opt
#     [  100/1323]  cost: 24,453
#     [  200/1323]  cost: 49,908
#     [  300/1323]  cost: 79,260
#     [  400/1323]  cost: 103,595
#     [  500/1323]  cost: 129,893
#     [  600/1323]  cost: 150,438
#     [  700/1323]  cost: 172,177
#     [  800/1323]  cost: 199,153
#     [  900/1323]  cost: 229,530
#     [ 1000/1323]  cost: 255,676
#     [ 1100/1323]  cost: 281,201
#     [ 1200/1323]  cost: 306,625
#     [ 1300/1323]  cost: 327,547
#     Pass 1: 342,239 -> 297,963  delta=44,276  (7.9s)
#     Pass 2: 297,963 -> 289,572  delta=8,391  (2.2s)
#     Pass 3: 289,572 -> 290,562  delta=-990  (0.6s)
#   [CI+3opt] Tour validation: valid
#
#  FI
#     [  100/1323]  cost: 149,921
#     [  200/1323]  cost: 198,439
#     [  300/1323]  cost: 230,497
#     [  400/1323]  cost: 260,174
#     [  500/1323]  cost: 279,451
#     [  600/1323]  cost: 292,829
#     [  700/1323]  cost: 302,271
#     [  800/1323]  cost: 309,299
#     [  900/1323]  cost: 315,237
#     [ 1000/1323]  cost: 319,482
#     [ 1100/1323]  cost: 322,489
#     [ 1200/1323]  cost: 324,487
#     [ 1300/1323]  cost: 325,923
#   [FI] Tour validation: valid
#
#  FI+3opt
#     [  100/1323]  cost: 149,921
#     [  200/1323]  cost: 198,439
#     [  300/1323]  cost: 230,497
#     [  400/1323]  cost: 260,174
#     [  500/1323]  cost: 279,451
#     [  600/1323]  cost: 292,829
#     [  700/1323]  cost: 302,271
#     [  800/1323]  cost: 309,299
#     [  900/1323]  cost: 315,237
#     [ 1000/1323]  cost: 319,482
#     [ 1100/1323]  cost: 322,489
#     [ 1200/1323]  cost: 324,487
#     [ 1300/1323]  cost: 325,923
#     Pass 1: 326,458 -> 307,018  delta=19,440  (6.6s)
#     Pass 2: 307,018 -> 298,646  delta=8,372  (1.3s)
#     Pass 3: 298,646 -> 295,288  delta=3,358  (0.6s)
#     Pass 4: 295,288 -> 294,563  delta=725  (0.4s)
#     Pass 5: 294,563 -> 293,789  delta=774  (0.2s)
#     Pass 6: 293,789 -> 293,072  delta=717  (0.1s)
#     Pass 7: 293,072 -> 293,172  delta=-100  (0.1s)
#   [FI+3opt] Tour validation: valid
#
# Dataset: rl1323  (optimal = 270,199)
#   Pipeline                  Init Cost   Final Cost  Improv%     Gap%   Time(s)
#   -----------------------------------------------------------------------------
#   NI                          352,638      352,638    0.00%   30.51%       0.9s
#   NI+2opt                     352,638      306,924   12.96%   13.59%       1.5s
#   NI+3opt                     352,638      293,791   16.69%    8.73%      11.7s
#   CI                          342,239      342,239    0.00%   26.66%     171.3s
#   CI+3opt                     342,239      290,562   15.10%    7.54%     183.2s
#   FI                          326,458      326,458    0.00%   20.82%       0.9s
#   FI+3opt                     326,458      293,172   10.20%    8.50%      10.8s
#
# Full pipeline comparison - final tour costs  (* = best for that dataset)
#
#   Dataset               NI     NI+2opt     NI+3opt          CI     CI+3opt          FI     FI+3opt
#   ------------------------------------------------------------------------------------------------
#   berlin52          8,991       8,836       7,959*      9,004       7,959*      8,275       8,146
#   bier127         145,730     135,386     122,491     140,647     126,596     129,266     120,492*
#   gil262            2,913       2,638       2,494*      2,790       2,531       2,554       2,503
#   linhp318         52,330      47,779      43,673      49,470      44,235      45,154      43,646*
#   pr439           132,781     124,479     119,344     130,184     118,037     120,524     115,132*
#   rat575            8,477       7,637       7,241       7,981       7,189       7,496       7,129*
#   d657             60,355      56,360      52,306      57,964      52,414      53,508      52,183*
#   rat783           10,877       9,918       9,387      10,384       9,331       9,731       9,322*
#   pr1002          307,430     290,433     277,340     304,828     278,682     284,485     271,173*
#   rl1323          352,638     306,924     293,791     342,239     290,562*    326,458     293,172
